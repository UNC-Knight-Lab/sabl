# %%
import numpy as np
import pandas as pd
from sabl.sabl import BarcodeSplitter

# %%
# define sequences preceding the barcodes
backbones = ['CGTCCTGA', 'ACGTGTTC', 'TCTCGTCC', 'CACACGAG']
ref_barcodes = pd.read_excel("sample_data/reference_barcodes.xlsx")

# %%
# read in sequences and initialize barcode arrays
barcode = BarcodeSplitter(backbones, ref_barcodes)
path= "sample_data/R1.txt"
barcode.read_sequences(path)

# extract barcodes for each sequence and backbone
barcode.split_count()
barcode.export_results("sample_data/outputs")
# Out:
# Total sequences: 177069
# Total success: 144353 (81.52358685032388%)
# Total fail: 32716 (18.476413149676116%)
# Size fail: 25049 (14.14646267839091%)
# Sequence match fail: 7667 (4.329950471285205%)
# Text file saved to: sample_data/outputs/QC.txt
# Excel file saved to: sample_data/outputs/barcodes.xlsx
# Excel file with match counts saved to: sample_data/outputs/frequency.xlsx
